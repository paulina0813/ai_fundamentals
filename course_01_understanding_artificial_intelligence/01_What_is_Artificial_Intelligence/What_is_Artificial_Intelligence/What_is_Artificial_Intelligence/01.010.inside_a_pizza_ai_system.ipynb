# %% [markdown]
# # Inside a pizza AI system
#
# A pizza chain plans to build an AI system to predict stock availability for toppings and optimize store revenue while reducing food waste due to toppings degradation.
#
# ## Instructions
# As the AI project leader for this initiative, your first task is to classify the following cards as the inputs, process steps, or outputs for the predictive algorithm under this AI system.
#
# ## Table
#
# |Item||Inputs|Process|Outputs|
# |---|---|---|---|
# |Aggregating data about past pepperoni stock and its frequency in order history for the past week| |X| |
# |Forecasting the pepperoni stock per store over the next week| |X| |
# |Orders history|X| | |
# |An estimate of pepperoni stock levels per store over the next week| | |X|
# |Daily stock levels of pepperoni per store|X| | |
# |
