# %% [markdown]
# # AI at work
#
# AI can perform many tasks, such as making predictions, recognizing patterns, optimizing processes, and automating repetitive work.
#
# Which AI capability is most essential for a system that helps a delivery company find the fastest routes for their drivers?
#
# ## Possible Answers
# 1. Pattern recognition
# 2. Optimization
# 3. Automation
# 4. Inference
#
# ## Correct Answer
# 2. Optimization
