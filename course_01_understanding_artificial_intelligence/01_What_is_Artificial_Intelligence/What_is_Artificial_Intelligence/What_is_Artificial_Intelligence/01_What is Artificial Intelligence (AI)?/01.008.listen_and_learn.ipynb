# %% [markdown]
# # Listen and Learn
#
# AI is made up of different areas that work together to create smart systems. Some AI applications combine multiple fields to achieve their goals. Let's see how different AI fields connect in real-world scenarios.
#
# ## Instructions
# Starting with the earliest step at the top, sort to show how AI helps a voice assistant understand and respond to a user.
#
# ## Items
# 1. Deep Learning - AI improves its ability to understand speech patterns and user intent
# 2. Speech or Text Output - AI generates a response, either through text or spoken words
# 3. Knowledge Representation & Reasoning - AI processes the information and determines the best response
# 4. Natural Language Processing (NLP) - AI interprets and understands the user's spoken or written words
#
# ## Ordered Items
# 4. Natural Language Processing (NLP) - AI interprets and understands the user's spoken or written words
# 3. Knowledge Representation & Reasoning - AI processes the information and determines the best response
# 1. Deep Learning - AI improves its ability to understand speech patterns and user intent
# 2. Speech or Text Output - AI generates a response, either through text or spoken words
