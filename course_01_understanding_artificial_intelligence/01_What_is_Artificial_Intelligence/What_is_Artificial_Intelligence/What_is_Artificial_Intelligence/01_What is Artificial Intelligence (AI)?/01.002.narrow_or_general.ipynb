# %% [markdown]
# # Narrow or General
#
# AI comes in different forms, but not all AI is created equal! Some AI systems are designed for specific tasks, while others (in theory) could match human intelligence
#
# ## Instructions
#
# Sort the following AI types into the correct categories
#
# |Item|Artificial Narrow Intelligence (ANI)|Artificial General Intelligence (AGI)|
# |---|---|---|
# |AI that surpasses human intelligence in all areas| |X|
# |Chatbots like Chat GPT|X| |
# |Self-driving cars|X| |
# |A fully sentinent robot| |X|
