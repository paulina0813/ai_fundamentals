# %% [markdown]
# # AI in Action
#
# AI is used for many tasks, including making predictions, recognizing patterns, and automating repetitive work. Each of these capabilities has different real-world applications.
#
# ## Instructions
# Sort each example into the correct category.
#
# |Item|Predictions & Inference|Automation|
# |---|---|---|
# |Suggesting movies based on your past viewing history|X| |
# |Forecasting next month's sales for a retail store|X| |
# |A chatbot responding to frequently asked customer questions| |X|
# |Automatically sorting incoming emails into spam and primary folders| |X|
