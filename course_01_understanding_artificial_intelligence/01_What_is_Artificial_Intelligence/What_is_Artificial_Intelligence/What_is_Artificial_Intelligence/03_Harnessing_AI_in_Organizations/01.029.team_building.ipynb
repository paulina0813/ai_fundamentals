# %% [markdown]
# # Team building!
#
# **Zen-wanders**, the AI-driven firm creating personalized immersive experiences inspired by Eastern Asian cultures, is growing fast!
#
# The AI department is expanding. Iwan, the AI lead, is welcoming six new colleagues; and creating leadership, execution, and support subdivisions.
#
# ## Instructions
# Help Iwan drag the profiles of the six new colleagues in their most suitable subdivision.
#
# ## Table
#
# |Item|Leadership|Execution and MLOps|Support|
# |---|---|---|---|
# |Max, a data scientist experienced with tuning and optimizing predictive ML models| |X| |
# |Nathan, a Machine Learning engineer who dominates the art of containerizing trained ML models to put them in production| |X| |
# |Carlos, a domain expert with two degrees in East Asian arts and tourism| | |X |
# |Nichole, a project coordinator, specialized in AI projects for product personalization| |X| |
# |Shun, an AI ethics officers with a Masters in Technology Low Studies| | |X|
# |Cassey, an AI manager who loves looking at the big picture of the entire AI architecture and data workflow pipelines|X| | |
