# %% [markdown]
# # Deep Learning is here to stay
#
# Deep Learning is here to stay: besides all supervised and unsupervised learning tasks, it also makes it possible to do things that were unimaginable years ago. Here are five different real-world applications of deep learning:
#
# 1. Design an original t-shirt.
#
# 2. Find out the shopping style that best describes you.
#
# 3. Write a Cervantes novel-style fictitious piece of text.
#
# 4. Dynamically assign hotel room and flight prices in a booking portal.
#
# 5. Unlock your cellphone with your face.
#
# ## Instructions
# Arrange the deep learning techniques and types of models on the right-hand side in the right order to match the above five applications.
#
# ## Items
# 1. Multi-class classification models
# 2. Regression
# 3. Object recognition in visual data
# 4. Generative AI models for creating images from text
# 5. Generative AI: Large Language Models
#
# ## Ordered Items
# 4. Generative AI models for creating images from text
# 1. Multi-class classification models
# 5. Generative AI: Large Language Models
# 2. Regression
# 3. Object recognition in visual data
