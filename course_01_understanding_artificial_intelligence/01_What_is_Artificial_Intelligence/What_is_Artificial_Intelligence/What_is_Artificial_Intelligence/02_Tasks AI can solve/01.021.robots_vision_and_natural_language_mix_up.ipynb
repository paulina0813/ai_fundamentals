# %% [markdown]
# # Robots, vision and natural language mix-up
#
# The following cards showcase examples of AI interacting with the physical environment, humans, or the digital environment.
#
# ## Instructions
# Drag each card into its most related AI area: robotics or Natural Language Processing (NLP).
#
# ## Table
#
# |Item|Robotics|NLP|
# |---|---|---|
# |An autonomous drone navigating between the dense foliage of crops|X| |
# |An autonomous forestry wehicle that navigates a dense forest|X| |
# |A conversation between a humanoid robot and a human in a tech convention| |X|
# |Assembling a small piece of furniture without human intervention|X| |
