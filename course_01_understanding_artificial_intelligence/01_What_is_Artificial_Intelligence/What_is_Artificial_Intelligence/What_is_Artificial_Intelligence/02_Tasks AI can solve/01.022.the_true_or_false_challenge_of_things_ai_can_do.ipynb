# %% [markdown]
# # The True-False challenge of things AI can do
#
# There is an increasing range of tasks AI systems and algorithms can help address, a vast majority of which are heavily data-driven. Always bear in mind that many practical applications involve the combined use of several techniques and tasks seen in this chapter.
#
# ## Instructions
# Classify whether each statement is true or false.
#
# ## Table
#
# |Item|True|False|
# |---|---|---|
# |Estimating a house price for sale based on data about other house prices and their characteristics is an example of a classification task| |X|
# |An AI system is built on algorithms, making every algorithm fundamental to the system's core| |X|
# |The process of adding relevant labels to the data to facilitate their understanding by AI systems is known as data annotation|X| |
# |Summarizing a text, answering questions about it, or being asked to write an engaging tweet, are examples of tasks a Large Language Model can do|X| |
