# %% [markdown]
# # Opening the Open Data doors
#
# Ever heard of Open Data Policies?
#
# Open data play a central role in AI democratization: the idea refers to enabling unrestricted access to non-sensitive data held by the government to the wider public, including citizens, research institutions, and organizations.
#
# Open data policies bring several benefits, including data availability, innovation and collaboration, equal opportunities and stimulating economic growth, along with transparency.
#
# However, not all data can be open data, for reasons like sensitive information, security, legal and commercial restrictions. Your next task is to select which of the following examples of datasets are suitable to become Open Data sources accessible by everyone.
#
# ## Possible Answers
# 1. Climate data: historical weather records and real-time weather observations geographically organized
# 2. Government budget and expenditure data
# 3. Environmental data: air quality, water quality, biodiversity indices, etc.
# 4. Patient medical records and healthcare data
# 5. Proprietary business data, including projects, financial records and data owned by clients and customers
# 6. Classified national security data related to national security, defense, and intelligence
# 7. Transportation data: public transportation schedules, routes, real-time traffic conditions, and public bus location data
#
# ## Correct Answers
# 1. Climate data: historical weather records and real-time weather observations geographically organized
# 2. Government budget and expenditure data
# 3. Environmental data: air quality, water quality, biodiversity indices, etc.
# 7. Transportation data: public transportation schedules, routes, real-time traffic conditions, and public bus location data
