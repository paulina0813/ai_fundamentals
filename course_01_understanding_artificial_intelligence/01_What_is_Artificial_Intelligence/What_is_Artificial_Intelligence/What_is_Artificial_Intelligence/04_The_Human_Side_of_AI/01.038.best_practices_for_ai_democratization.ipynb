# %% [markdown]
# # Best practices for AI democratization
#
# The attractive aspects and recent advances made by AI have caught the attention of the digital cabinet office, whose members are interested in presenting a proposal about nationwide AI democratization.
#
# The cabinet hired you, an expert in AI and data democratization, to advise them on the best practices to adopt to drive a successful democratization program of AI technologies.
#
# ## Instructions
# Classify the following initiatives depending on whether they are aligned or not aligned with embracing a strategy for AI democratization that benefits citizens.
#
# ## Table
#
# |Items|Aligned with AI democratization|Not aligned with AI democratization|
# |---|---|---|
# |Restrict access to AI technologies and knowledge only to exclusive groups with a deep technical understanding of them| |X|
# |Promoting AI courses at different levels for citizens of all knowledge backgrounds|X| |
# |Implement Open Data Policies that promote the availability and citizenship access to data held by the public sector|X| |
# |Encourage public-private partnerships between government, private sector firms, and academic institutions to spread AI innovation|X| |
# |Not disclosing information about data sources, algorithms, or decisions made by a public AI tool, to prevent possible protests or complaints| |X|
