# %% [markdown]
# # The thousand faces of sustainable AI
#
# When the design and utilization decisions of AI systems are put in the right hands (or minds), this transformative technology can become a powerful facilitator of sustainability in all of its 17 forms:
#
# Now you'll be introduced to five examples of initiatives where AI can facilitate one of the five specific Sustainable Development Goals listed below:
#
# 1. **SDG 3: Good health and well-being.**
# 2. **SDG 7: Affordable and clean energy.**
# 3. **SDG 9: Industry, Innovation, and Infrastructure.**
# 4. **SDG 11: Sustainable cities and communities.**
# 5. **SDG 15: Life on land.**
#
# ## Instructions
# Drag and order the five AI initiatives to match their associated SDG in the above list.
#
# ## Items
# 1. A non-intrusive AI and sensor network deployed in a forest area, whose algrithms can aid in biodiversity monitoring and habitat protection
# 2. A predictive manufacturing maintenance system that anticipates potential disruption and failures that affect production in an automobile factory
# 3. AI-powered smart grids that optimize energy distribution and predict energy demand at different granularity levels including households
# 4. Early brain tumor detection through image analysis by combining computer vision and deep learning image classifiers
# 5. A smart transportation service underpinned by AI and IoT technologies that informs users about the fastest options in real-time
#
# ## Ordered Items
# 4. Early brain tumor detection through image analysis by combining computer vision and deep learning image classifiers
# 3. AI-powered smart grids that optimize energy distribution and predict energy demand at different granularity levels including households
# 2. A predictive manufacturing maintenance system that anticipates potential disruption and failures that affect production in an automobile factory
# 5. A smart transportation service underpinned by AI and IoT technologies that informs users about the fastest options in real-time
# 1. A non-intrusive AI and sensor network deployed in a forest area, whose algrithms can aid in biodiversity monitoring and habitat protection
